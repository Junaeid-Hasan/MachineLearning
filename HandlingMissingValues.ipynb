# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("lung_disease_data.csv")
df.head()
# Out:
#     Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0  71.0  Female             No           4.49         COPD        Therapy
# 1  34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2  80.0    Male            Yes           1.95         COPD            NaN
# 3  40.0  Female            Yes            NaN   Bronchitis     Medication
# 4  43.0    Male            Yes           4.60         COPD        Surgery
#
#    Hospital Visits Recovered
# 0             14.0       Yes
# 1              7.0        No
# 2              4.0       Yes
# 3              1.0        No
# 4              NaN       Yes

# %%
row,col=df.shape
print(f"Rows: {row} and Columns: {col}")
# Out:
# Rows: 5200 and Columns: 8

# %%
df[(df["Gender"] != "Male") & (df["Gender"] != "Female")]
# Out:
#        Age Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 18    68.0    NaN            Yes           5.67    Pneumonia     Medication
# 58    53.0    NaN             No           1.51    Pneumonia        Surgery
# 65    72.0    NaN            Yes           1.25  Lung Cancer        Surgery
# 79    27.0    NaN            Yes           4.69  Lung Cancer        Surgery
# 83    24.0    NaN             No           3.49       Asthma     Medication
# ...    ...    ...            ...            ...          ...            ...
# 5152  60.0    NaN            Yes           1.25    Pneumonia        Surgery
# 5154  20.0    NaN            Yes           1.97  Lung Cancer        Therapy
# 5172   NaN    NaN             No           3.81   Bronchitis        Surgery
# 5179  75.0    NaN            Yes           2.29   Bronchitis        Therapy
# 5196  21.0    NaN            Yes           1.50         COPD     Medication
#
#       Hospital Visits Recovered
# ...

# %%
df[df["Age"]>90]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Smoking Status, Lung Capacity, Disease Type, Treatment Type, Hospital Visits, Recovered]
# Index: []

# %%
df[df["Lung Capacity"]>6]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Smoking Status, Lung Capacity, Disease Type, Treatment Type, Hospital Visits, Recovered]
# Index: []

# %%
df.fillna({
    "Hospital Visits":df["Hospital Visits"].mean(),
    "Lung Capacity":df["Lung Capacity"].mean(),
},inplace=True
)

# %%
df.fillna(method="ffill",inplace=True)
# Out:
# /tmp/ipykernel_4863/1844562654.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill",inplace=True)

# %%
df.head()
# Out:
#     Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0  71.0  Female             No       4.490000         COPD        Therapy
# 1  34.0  Female            Yes       3.501865   Bronchitis        Surgery
# 2  80.0    Male            Yes       1.950000         COPD        Surgery
# 3  40.0  Female            Yes       3.501865   Bronchitis     Medication
# 4  43.0    Male            Yes       4.600000         COPD        Surgery
#
#    Hospital Visits Recovered
# 0        14.000000       Yes
# 1         7.000000        No
# 2         4.000000       Yes
# 3         1.000000        No
# 4         7.528571       Yes

# %%
df.isnull().sum()
# Out:
# Age                0
# Gender             0
# Smoking Status     0
# Lung Capacity      0
# Disease Type       0
# Treatment Type     0
# Hospital Visits    0
# Recovered          0
# dtype: int64

# %%
df.loc[df["Age"]<40]
# Out:
#        Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 1     34.0  Female            Yes       3.501865   Bronchitis        Surgery
# 5     22.0  Female             No       3.650000   Bronchitis     Medication
# 8     21.0  Female             No       4.050000  Lung Cancer     Medication
# 11    21.0    Male             No       1.370000    Pneumonia        Surgery
# 22    34.0    Male             No       3.200000    Pneumonia        Surgery
# ...    ...     ...            ...            ...          ...            ...
# 5190  27.0    Male             No       5.260000         COPD        Therapy
# 5191  29.0  Female             No       3.360000       Asthma        Therapy
# 5192  31.0  Female             No       1.510000    Pneumonia        Surgery
# 5193  35.0  Female            Yes       3.800000         COPD        Therapy
# 5196  21.0    Male            Yes       1.500000         COPD     Medication
#
#       Hospital Visits Recovered
# ...

# %%
df.head()
# Out:
#     Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0  71.0  Female             No       4.490000         COPD        Therapy
# 1  34.0  Female            Yes       3.501865   Bronchitis        Surgery
# 2  80.0    Male            Yes       1.950000         COPD        Surgery
# 3  40.0  Female            Yes       3.501865   Bronchitis     Medication
# 4  43.0    Male            Yes       4.600000         COPD        Surgery
#
#    Hospital Visits Recovered
# 0        14.000000       Yes
# 1         7.000000        No
# 2         4.000000       Yes
# 3         1.000000        No
# 4         7.528571       Yes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5200, step=1)

# %%
df.set_index("Age",inplace=True)

# %%
df.head()
# Out:
#       Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# Age
# 71.0  Female             No       4.490000         COPD        Therapy
# 34.0  Female            Yes       3.501865   Bronchitis        Surgery
# 80.0    Male            Yes       1.950000         COPD        Surgery
# 40.0  Female            Yes       3.501865   Bronchitis     Medication
# 43.0    Male            Yes       4.600000         COPD        Surgery
#
#       Hospital Visits Recovered
# Age
# 71.0        14.000000       Yes
# 34.0         7.000000        No
# 80.0         4.000000       Yes
# 40.0         1.000000        No
# 43.0         7.528571       Yes

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#       Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# Age
# 71.0  Female             No       4.490000         COPD        Therapy
# 34.0  Female            Yes       3.501865   Bronchitis        Surgery
# 80.0    Male            Yes       1.950000         COPD        Surgery
# 40.0  Female            Yes       3.501865   Bronchitis     Medication
# 43.0    Male            Yes       4.600000         COPD        Surgery
#
#       Hospital Visits Recovered
# Age
# 71.0        14.000000       Yes
# 34.0         7.000000        No
# 80.0         4.000000       Yes
# 40.0         1.000000        No
# 43.0         7.528571       Yes

# %%
df.nunique()
# Out:
# Gender               2
# Smoking Status       2
# Lung Capacity      502
# Disease Type         5
# Treatment Type       3
# Hospital Visits     15
# Recovered            2
# dtype: int64

# %%
x=df.head(10)
x.plot()
# Out:
# <Axes: xlabel='Age'>

# %%
x.interpolate().plot(title="Interpolatted")
# Out:
# /tmp/ipykernel_4863/2394022259.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   x.interpolate().plot(title="Interpolatted")
# <Axes: title={'center': 'Interpolatted'}, xlabel='Age'>
